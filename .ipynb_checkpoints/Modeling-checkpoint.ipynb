# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV, RidgeCV, LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score, r2_score
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
df = pd.read_csv('./datasets/df.csv')
fd = pd.read_csv('./datasets/fd.csv')

# %%
cols = pd.Series(fd.columns.values)

# %%
plt.pyplot.figure(figsize=(12,150))
sns.heatmap(df.corr()[['SalePrice']].sort_values('SalePrice'),
            vmin=-1, annot=True, cmap='coolwarm');

# %%
X = df.drop(columns=['SalePrice'], axis=1)
y = df['SalePrice']

# %%
ss = StandardScaler()
X = pd.DataFrame(ss.fit_transform(X))
fd = pd.DataFrame(ss.transform(fd))

# %%
pca = PCA()

# %%
pca.fit(X)

# %%
Z = pd.DataFrame(pca.transform(X))

# %%
fd = pd.DataFrame(pca.transform(fd))

# %%
Z_train, Z_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
lr = LinearRegression()
lasso = LassoCV()
ridge = RidgeCV()

# %%
lr.fit(X_train, y_train)

# %%
lasso.fit(X_train, y_train)

# %%
ridge.fit(X_train, y_train)

# %%
cross_val_score(lr, X_train, y_train, cv=5).mean()

# %%
cross_val_score(lasso, X_train, y_train, cv=5).mean()

# %%
cross_val_score(ridge, X_train, y_train, cv=5).mean()

# %%
# Score on training set. (We'll use R^2 for the score today.)
print(f'Training Score: {round(r2_score(y_train, lr.predict(X_train)), 4)}.')

# %%
# Score on training set. (We'll use R^2 for the score today.)
print(f'Training Score: {round(r2_score(y_train, lasso.predict(X_train)), 4)}.')

# %%
# Score on training set. (We'll use R^2 for the score today.)
print(f'Training Score: {round(r2_score(y_train, ridge.predict(X_train)), 4)}.')

# %%
r2_score()

# %%
# Score on training set. (We'll use R^2 for the score today.)
print(f'Training Score: {round(r2_score(y_test, df['mean SalePrice'][:y_test.shape[0]]), 4)}.')

# %%
df['mean SalePrice'] = df['SalePrice'].mean()

# %%
type(X_test)

# %%
# Score on training set. (We'll use R^2 for the score today.)
print(f'Training Score: {round(r2_score(y_test, lasso.predict(X_test)), 4)}.')

# %%
# Score on training set. (We'll use R^2 for the score today.)
print(f'Training Score: {round(r2_score(y_train, lm.predict(X_train)), 4)}.')

# %%
X = df.drop(columns=['SalePrice'], axis=1)
y = df['SalePrice']

# %%
ss = StandardScaler()
ss.fit(X)
X_sc = ss.transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_sc, y, random_state=42)

# %%
lr = LinearRegression()
lasso = LassoCV()
ridge = RidgeCV()

# %%
cross_val_score(lr, X_train, y_train, cv=5).mean()

# %%
cross_val_score(lasso, X_train, y_train, cv=5).mean()

# %%
cross_val_score(ridge, X_train, y_train, cv=5).mean()

# %%
ridge.fit(X_train, y_train);

# %%
cross_val_score(ridge, X_train, y_train, cv=5).mean()

# %%
ridge.score(X_train, y_train)

# %%
ridge.score(X_val, y_val)

# %%
pred = ridge.predict(X_val)

# %%
residuals = y_val - pred

# %%
plt.pyplot.scatter(pred, residuals)
plt.pyplot.axhline(c='r');

# %%
X = df.drop(columns=['SalePrice'], axis=1)
y = np.log(df['SalePrice'])

# %%
X = ss.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y,random_state=42)

# %%
cross_val_score(lr, X_train, y_train, cv=5).mean()

# %%
cross_val_score(lasso, X_train, y_train, cv=5).mean()

# %%
cross_val_score(ridge, X_train, y_train, cv=5).mean()

# %%
lasso.fit(X_train, y_train)

# %%
preds = lasso.predict(X_val)

# %%
plt.pyplot.scatter(preds, residuals)
plt.pyplot.axhline(c='r');

# %%
df['SalePrice'] = np.log(df['SalePrice'])

# %%
X = df.drop(columns=['SalePrice'], axis=1)
y = df['SalePrice']

# %%
ss = StandardScaler()
X = pd.DataFrame(ss.fit_transform(X))
fd = pd.DataFrame(ss.fit_transform(fd))

# %%
X = X.rename(columns=cols)
fd = fd.rename(columns=cols)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

# %%
preds = lr.predict(X_test)

# %%
ss.inverse_transform(preds)

# %%
r2_score(y_val, preds)
